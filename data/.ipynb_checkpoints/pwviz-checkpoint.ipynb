# %%
import re

# %%
lines = [line.strip() for line in open('xom-all-flat-mod-pnums.xml', 'r').readlines()]

# %%
lines = re.split(r'<', ' '.join(lines))

# %%
for line in lines:
    parts = re.split('>', line)
    print('TAG', parts[0])
    #if len(parts) > 1:
    print('TXT', parts[1])
# Out:
# TAG
# TAG ?xml version="1.0" encoding="UTF-8"?
# TXT
# TAG TEI xmlns="http://www.tei-c.org/ns/1.0" xmlns:xi="http://www.w3.org/2001/XInclude"
# TXT
# TAG teiHeader
# TXT
# TAG fileDesc
# TXT
# TAG titleStmt
# TXT
# TAG title
# TXT Arte de las tres lenguas kakchiquel, quiché y tzutuhil, v.2 Popol vuh; and Escolios a la historia de el origen de los Indios.
# TAG /title
# TXT
# TAG author
# TXT Ximénez, Francisco
# TAG /author
# TXT
# TAG /titleStmt
# TXT
# TAG publicationStmt
# TXT
# TAG publisher
# TXT The Newberry Library
# TAG /publisher
# TXT
# TAG pubPlace
# TXT Chicago, Illinois, USA
# TAG /pubPlace
# TXT
# TAG /publicationStmt
# TXT
# TAG sourceDesc default="false"
# TXT
# TAG p part="N"
# ...
